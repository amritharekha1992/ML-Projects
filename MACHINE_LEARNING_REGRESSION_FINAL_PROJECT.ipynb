# %% [markdown]
# Objective: The data is related to Chevrolet cars. The regression goal is to predict the price(MSRP)(variable y) of different Chevrolet models based on a number of car features.

# %% [markdown]
# Data source : https://www.kaggle.com/jshih7/car-price-prediction/data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
car = pd.read_csv("car_data.csv")

# %%
car.head()
# Out:
#         Make        Model  Year  Engine Fuel Type  Engine HP  \
# 0  Chevrolet  Astro Cargo  2003  regular unleaded      190.0
# 1  Chevrolet  Astro Cargo  2003  regular unleaded      190.0
# 2  Chevrolet  Astro Cargo  2004  regular unleaded      190.0
# 3  Chevrolet  Astro Cargo  2004  regular unleaded      190.0
# 4  Chevrolet  Astro Cargo  2005  regular unleaded      190.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0         AUTOMATIC  rear wheel drive              3.0
# 1               6.0         AUTOMATIC   all wheel drive              3.0
# 2               6.0         AUTOMATIC   all wheel drive              3.0
# 3               6.0         AUTOMATIC  rear wheel drive              3.0
# 4               6.0         AUTOMATIC  rear wheel drive              3.0
#
#   Market Category Vehicle Size  Vehicle Style  highway MPG  city mpg  \
# 0             NaN        Large  Cargo Minivan         21.0      15.0
# 1             NaN        Large  Cargo Minivan         18.0      14.0
# 2             NaN        Large  Cargo Minivan         18.0      14.0
# 3             NaN        Large  Cargo Minivan         19.0      14.0
# 4             NaN        Large  Cargo Minivan         20.0      15.0
#
#    Popularity   MSRP
# 0      1385.0  22050
# 1      1385.0  24450
# 2      1385.0  25195
# 3      1385.0  22695
# 4      1385.0  22930

# %%
car.shape
# Out:
# (1123, 16)

# %%
# Finding the null values in the data set
car.isnull().sum()
# Out:
# Make                 148
# Model                  0
# Year                   0
# Engine Fuel Type       0
# Engine HP             26
# Engine Cylinders      25
# Transmission Type      0
# Driven_Wheels          0
# Number of Doors       11
# Market Category      501
# Vehicle Size           0
# Vehicle Style          0
# highway MPG           29
# city mpg              35
# Popularity           314
# MSRP                   0
# dtype: int64

# %%
car.describe()
# Out:
#               Year    Engine HP  Engine Cylinders  Number of Doors  \
# count  1123.000000  1097.000000       1098.000000      1112.000000
# mean   2010.087266   248.202370          5.915301         3.394784
# std       7.172775   107.464164          1.616664         0.882722
# min    1990.000000    55.000000          0.000000         2.000000
# 25%    2005.000000   165.000000          4.000000         2.000000
# 50%    2015.000000   230.000000          6.000000         4.000000
# 75%    2016.000000   295.000000          8.000000         4.000000
# max    2017.000000   650.000000          8.000000         4.000000
#
#        highway MPG     city mpg  Popularity          MSRP
# count  1094.000000  1088.000000       809.0   1123.000000
# mean     25.763254    19.084559      1385.0  28350.385574
# std       9.498672    10.494061         0.0  17289.812251
# min      15.000000    11.000000      1385.0   2000.000000
# 25%      21.000000    15.000000      1385.0  18474.500000
# 50%      23.000000    17.000000      1385.0  26430.000000
# 75%      29.000000    20.000000      1385.0  36690.000000
# max     110.000000   128.000000      1385.0  92395.000000

# %%
car.dtypes
# Out:
# Make                  object
# Model                 object
# Year                   int64
# Engine Fuel Type      object
# Engine HP            float64
# Engine Cylinders     float64
# Transmission Type     object
# Driven_Wheels         object
# Number of Doors      float64
# Market Category       object
# Vehicle Size          object
# Vehicle Style         object
# highway MPG          float64
# city mpg             float64
# Popularity           float64
# MSRP                   int64
# dtype: object

# %%
car.columns.values
# Out:
# array(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size',
#        'Vehicle Style', 'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype=object)

# %% [markdown]
# Make                Car Brand (Categorical): Chevrolet
# Model               Different Chevrolet Car Models (Categorical)
# Year                The year in which the model was released (Numerical)
# Engine Fuel Type    Car fuel types in our dataset (Categorical) ('regular unleaded', 'flex-fuel (unleaded/E85)', 'electric',
#                     'premium unleaded (required)', 'premium unleaded (recommended)',
#                     'diesel', 'flex-fuel (unleaded/natural gas))
# Engine HP           This is the engine's horse power (Numerical)
# Engine Cylinders    No. of cylinders in the engine (Numerical)
# Transmission Type   Different transmission types (Categorical) - 'AUTOMATIC', 'MANUAL', 'DIRECT_DRIVE'
# Driven_Wheels       Type of driven wheels (Categorical)
# Number of Doors     (Numerical)
# Market Category     Different Market categories (Categorical) - 'Crossover,Flex Fuel', 'Hatchback', 'Performance',
#                     'Factory Tuner,High-Performance', 'High-Performance',
#                     'Factory Tuner,Performance', 'Diesel', 'Crossover', 'Flex Fuel',
#                     'Flex Fuel,Performance', 'Hybrid', 'Hatchback,Performance',
#                     'Luxury,Hybrid'
# Vehicle Size         Different vehicle sizes (Categorical) - 'Large', 'Compact', 'Midsize'
# Vehicle Style        Different vehicle styles (Categorical) - Cargo Minivan', 'Passenger Minivan', 'Crew Cab Pickup',
#                      '4dr Hatchback', 'Sedan', 'Coupe', '2dr SUV', '4dr SUV',
#                      'Convertible', 'Wagon', 'Cargo Van', 'Regular Cab Pickup',
#                      'Extended Cab Pickup', 'Passenger Van', '2dr Hatchback',
#                      'Convertible SU
# highway MPG          Highway Mileage (Numerical)
# city mpg             City Mileage (Numerical)
# Popularity           Market Popularity Code - (Numerical)
# MSRP                 Manufacturer Suggested Retail Price of the different Chevrolet car models

# %%
car = car.rename(columns= {"Engine Fuel Type":"Engine_Fuel_Type",
                             "Engine HP": "Engine_HP",
                             "Engine Cylinders": "Engine_Cylinders",
                             "Transmission Type": "Transmission_Type",
                             "Number of Doors" : "Number_of_Doors",
                             "Market Category": "Market_Category",
                             "Vehicle Size": "Vehicle_Size",
                             "Vehicle Style": "Vehicle_Style",
                             "highway MPG" : "highway_MPG",
                             "city mpg" : "city_mpg"})

# %%
car.columns.values
# Out:
# array(['Make', 'Model', 'Year', 'Engine_Fuel_Type', 'Engine_HP',
#        'Engine_Cylinders', 'Transmission_Type', 'Driven_Wheels',
#        'Number_of_Doors', 'Market_Category', 'Vehicle_Size',
#        'Vehicle_Style', 'highway_MPG', 'city_mpg', 'Popularity', 'MSRP'],
#       dtype=object)

# %%
car.Make.unique()
# Out:
# array(['Chevrolet', nan], dtype=object)

# %%
a =car.Model.unique()

# %%
a.count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-f11c6a8bc4f8> in <module>
# ----> 1 a.count()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'

# %%
car.Engine_Fuel_Type.unique()
# Out:
# array(['regular unleaded', 'flex-fuel (unleaded/E85)', 'electric',
#        'premium unleaded (required)', 'premium unleaded (recommended)',
#        'diesel', 'flex-fuel (unleaded/natural gas)'], dtype=object)

# %%
car.Transmission_Type.unique()
# Out:
# array(['AUTOMATIC', 'MANUAL', 'DIRECT_DRIVE'], dtype=object)

# %%
car.Number_of_Doors.unique()
# Out:
# array([ 3.,  4.,  2., nan])

# %%
car.Market_Category.unique()
# Out:
# array([nan, 'Crossover,Flex Fuel', 'Hatchback', 'Performance',
#        'Factory Tuner,High-Performance', 'High-Performance',
#        'Factory Tuner,Performance', 'Diesel', 'Crossover', 'Flex Fuel',
#        'Flex Fuel,Performance', 'Hybrid', 'Hatchback,Performance',
#        'Luxury,Hybrid'], dtype=object)

# %%
car.Vehicle_Size.unique()
# Out:
# array(['Large', 'Compact', 'Midsize'], dtype=object)

# %%
car.Vehicle_Style.unique()
# Out:
# array(['Cargo Minivan', 'Passenger Minivan', 'Crew Cab Pickup',
#        '4dr Hatchback', 'Sedan', 'Coupe', '2dr SUV', '4dr SUV',
#        'Convertible', 'Wagon', 'Cargo Van', 'Regular Cab Pickup',
#        'Extended Cab Pickup', 'Passenger Van', '2dr Hatchback',
#        'Convertible SUV'], dtype=object)

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Heat Map to find the correlation between the features

# %%
fig = plt.subplots(figsize = (20,20))
sns.set(font_scale=2.0)
sns.heatmap(car.corr(),square = True,cbar=True,annot=True,annot_kws={'size': 5})
plt.show()

# %% [markdown]
# Dropping the Make and Popularity as they have same value for all the observations and are insignificant for model training

# %%
car = car.drop(['Make','Popularity'], axis = 1)

# %%
car.dtypes
# Out:
# Model                 object
# Year                   int64
# Engine_Fuel_Type      object
# Engine_HP            float64
# Engine_Cylinders     float64
# Transmission_Type     object
# Driven_Wheels         object
# Number_of_Doors      float64
# Market_Category       object
# Vehicle_Size          object
# Vehicle_Style         object
# highway_MPG          float64
# city_mpg             float64
# MSRP                   int64
# dtype: object

# %%
categorcial_variables = ['Model']
for col in categorcial_variables:
    plt.figure(figsize=(10,25))
    sns.barplot(car[col].value_counts().values, car[col].value_counts().index)
    plt.title(col)
    plt.tight_layout()

# %% [markdown]
# Label Encoding is done on the categorical variables

# %%
car.head()
# Out:
#          Model  Year  Engine_Fuel_Type  Engine_HP  Engine_Cylinders  \
# 0  Astro Cargo  2003  regular unleaded      190.0               6.0
# 1  Astro Cargo  2003  regular unleaded      190.0               6.0
# 2  Astro Cargo  2004  regular unleaded      190.0               6.0
# 3  Astro Cargo  2004  regular unleaded      190.0               6.0
# 4  Astro Cargo  2005  regular unleaded      190.0               6.0
#
#   Transmission_Type     Driven_Wheels  Number_of_Doors Market_Category  \
# 0         AUTOMATIC  rear wheel drive              3.0             NaN
# 1         AUTOMATIC   all wheel drive              3.0             NaN
# 2         AUTOMATIC   all wheel drive              3.0             NaN
# 3         AUTOMATIC  rear wheel drive              3.0             NaN
# 4         AUTOMATIC  rear wheel drive              3.0             NaN
#
#   Vehicle_Size  Vehicle_Style  highway_MPG  city_mpg   MSRP
# 0        Large  Cargo Minivan         21.0      15.0  22050
# 1        Large  Cargo Minivan         18.0      14.0  24450
# 2        Large  Cargo Minivan         18.0      14.0  25195
# 3        Large  Cargo Minivan         19.0      14.0  22695
# 4        Large  Cargo Minivan         20.0      15.0  22930

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Dealing with the missing values

# %%
car['Engine_HP'] = car['Engine_HP'].fillna((car['Engine_HP'].mean()))
car['Engine_Cylinders'] = car['Engine_Cylinders'].fillna((car['Engine_Cylinders'].mean()))
car['Number_of_Doors'] = car['Number_of_Doors'].fillna((car['Number_of_Doors'].mean()))
car['highway_MPG'] = car['highway_MPG'].fillna((car['highway_MPG'].mean()))
car['city_mpg'] = car['city_mpg'].fillna((car['city_mpg'].mean()))

# %%
car.isnull().sum()
# Out:
# Model                  0
# Year                   0
# Engine_Fuel_Type       0
# Engine_HP              0
# Engine_Cylinders       0
# Transmission_Type      0
# Driven_Wheels          0
# Number_of_Doors        0
# Market_Category      501
# Vehicle_Size           0
# Vehicle_Style          0
# highway_MPG            0
# city_mpg               0
# MSRP                   0
# dtype: int64

# %% [markdown]
# Found the mode of Market category and replaced nan with that

# %%
car.Market_Category.mode()
# Out:
# 0    Flex Fuel
# dtype: object

# %%
car['Market_Category'].fillna('Flex Fuel', inplace=True)

# %%
car.isnull().sum()
# Out:
# Model                0
# Year                 0
# Engine_Fuel_Type     0
# Engine_HP            0
# Engine_Cylinders     0
# Transmission_Type    0
# Driven_Wheels        0
# Number_of_Doors      0
# Market_Category      0
# Vehicle_Size         0
# Vehicle_Style        0
# highway_MPG          0
# city_mpg             0
# MSRP                 0
# dtype: int64

# %%
car.Market_Category.unique()
# Out:
# array(['Flex Fuel', 'Crossover,Flex Fuel', 'Hatchback', 'Performance',
#        'Factory Tuner,High-Performance', 'High-Performance',
#        'Factory Tuner,Performance', 'Diesel', 'Crossover',
#        'Flex Fuel,Performance', 'Hybrid', 'Hatchback,Performance',
#        'Luxury,Hybrid'], dtype=object)

# %%
car.isnull().sum()
# Out:
# Model                0
# Year                 0
# Engine_Fuel_Type     0
# Engine_HP            0
# Engine_Cylinders     0
# Transmission_Type    0
# Driven_Wheels        0
# Number_of_Doors      0
# Market_Category      0
# Vehicle_Size         0
# Vehicle_Style        0
# highway_MPG          0
# city_mpg             0
# MSRP                 0
# dtype: int64

# %% [markdown]
# Label Encoding is on categorical features

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_X = LabelEncoder()
car['Model'] = labelencoder_X.fit_transform(car['Model'])
car['Engine_Fuel_Type'] = labelencoder_X.fit_transform(car['Engine_Fuel_Type'])
car['Transmission_Type'] = labelencoder_X.fit_transform(car['Transmission_Type'])
car['Driven_Wheels'] = labelencoder_X.fit_transform(car['Driven_Wheels'])
car['Market_Category'] = labelencoder_X.fit_transform(car['Market_Category'])
car['Vehicle_Size'] = labelencoder_X.fit_transform(car['Vehicle_Size'])
car['Vehicle_Style'] = labelencoder_X.fit_transform(car['Vehicle_Style'])

# %%
car.head()
# Out:
#    Model  Year  Engine_Fuel_Type  Engine_HP  Engine_Cylinders  \
# 0      1  2003                 6      190.0               6.0
# 1      1  2003                 6      190.0               6.0
# 2      1  2004                 6      190.0               6.0
# 3      1  2004                 6      190.0               6.0
# 4      1  2005                 6      190.0               6.0
#
#    Transmission_Type  Driven_Wheels  Number_of_Doors  Market_Category  \
# 0                  0              3              3.0                5
# 1                  0              0              3.0                5
# 2                  0              0              3.0                5
# 3                  0              3              3.0                5
# 4                  0              3              3.0                5
#
#    Vehicle_Size  Vehicle_Style  highway_MPG  city_mpg   MSRP
# 0             1              4         21.0      15.0  22050
# 1             1              4         18.0      14.0  24450
# 2             1              4         18.0      14.0  25195
# 3             1              4         19.0      14.0  22695
# 4             1              4         20.0      15.0  22930

# %%
car.shape
# Out:
# (1123, 14)

# %% [markdown]
# # Splitting the dataset into training and testing sets

# %%
X = car.drop(['MSRP'], axis=1)
y = car.MSRP

# %% [markdown]
# Outlier Detection

# %%
ax = X.plot(kind = 'box', figsize = (20,20), legend = True, fontsize = 10)
plt.show()

# %%
X_train_org, X_test_org, y_train, y_test = train_test_split(X, y, random_state =0, test_size = 0.2)

# %%
plt.subplot(1, 2, 1)
y_train.plot.hist(bins=50, figsize=(12, 6), edgecolor = 'white', range = [0, 5000])
plt.xlabel('price', fontsize=12)
plt.title('Price Distribution', fontsize=12)
plt.subplot(1, 2, 2)
np.log(y_train+1).plot.hist(bins=50, figsize=(12,6), edgecolor='white')
plt.xlabel('log(price+1)', fontsize=12)
plt.title('Price Distribution', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Price Distribution')

# %% [markdown]
# # Scaling the train and test data

# %% [markdown]
# The features is spread over a wide range of values. So, for normalization purpose we decided to use MinMaxScaler.

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train_org)
X_test = scaler.transform(X_test_org)

# %%
X_train.shape
# Out:
# (898, 13)

# %%
X_test.shape
# Out:
# (225, 13)

# %% [markdown]
# # KNN Regression

# %%
from sklearn.neighbors import KNeighborsRegressor
# %matplotlib inline
train_score_array = []
test_score_array = []

for k in range(1,100):
    knn_reg = KNeighborsRegressor(k)
    knn_reg.fit(X_train, y_train)
    train_score_array.append(knn_reg.score(X_train, y_train))
    test_score_array.append(knn_reg.score(X_test, y_test))

x_axis = range(1,100)
plt.plot(x_axis, train_score_array, c = 'g', label = 'Train Score')
plt.plot(x_axis, test_score_array, c = 'b', label = 'Test Score')
plt.legend()
plt.xlabel('k')
plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %% [markdown]
# Using Grid Search

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import GridSearchCV

kfold =KFold(n_splits=5, random_state=0)

param_grid={'n_neighbors':range(1,10)}

grid_search = GridSearchCV(KNeighborsRegressor(), param_grid, cv=kfold, return_train_score=True)
grid_search.fit(X_train,y_train)

test=cross_val_score(grid_search, X_test, y_test, cv=kfold).mean()

# %%
print("Train:",grid_search.best_score_)
print("Test",test)
print("parameters",grid_search.best_params_)
# Out:
# Train: 0.9389823821721689
# Test 0.8064827471194385
# parameters {'n_neighbors': 2}

# %%
# k = 2 is the best regressor
knn_reg = KNeighborsRegressor(9)
# Cross validation
scores = cross_val_score(knn_reg, X_train, y_train)
print("Cross-validation train_scores: {}".format(scores))
print("Average cross-validation train_scores: {:.2f}".format(scores.mean()))

scores = cross_val_score(knn_reg, X_test, y_test)
print("Cross-validation test_scores: {}".format(scores))
print("Average cross-validation train_scores: {:.2f}".format(scores.mean()))
mn ="KNN Regression"
# Out:
# Cross-validation train_scores: [0.90640253 0.89653367 0.92324999]
# Average cross-validation train_scores: 0.91
# Cross-validation test_scores: [0.79232739 0.83658546 0.66318779]
# Average cross-validation train_scores: 0.76
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
model_results = pd.DataFrame(columns=('S.No','Model_Name','Parameters', 'Train_Score', 'Test_Score'))

# %%
model_results.loc[len(model_results)]=[1,'KNN Regression',grid_search.best_params_,grid_search.best_score_,test]
model_results
# Out:
#   S.No      Model_Name          Parameters  Train_Score  Test_Score
# 0    1  KNN Regression  {'n_neighbors': 2}     0.938982    0.806483

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression, SGDRegressor

lreg = LinearRegression()
lreg.fit(X_train, y_train)
print('Train score:', lreg.score(X_train, y_train))
linear_train = lreg.score(X_train, y_train)
print('Test score: ', lreg.score(X_test, y_test))
linear_test = lreg.score(X_test, y_test)
# Cross validation
scores = cross_val_score(lreg, X_train, y_train)
print("Cross-validation train_scores: {}".format(scores))
print("Average cross-validation train_scores: {:.2f}".format(scores.mean()))

scores = cross_val_score(lreg, X_test, y_test)
print("Cross-validation test_scores: {}".format(scores))
print("Average cross-validation train_scores: {:.2f}".format(scores.mean()))
# Out:
# Train score: 0.8784156201461062
# Test score:  0.8615964616962237
# Cross-validation train_scores: [0.89913692 0.8576135  0.86279383]
# Average cross-validation train_scores: 0.87
# Cross-validation test_scores: [0.86446694 0.86857464 0.85186775]
# Average cross-validation train_scores: 0.86
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
# INCLUDE IF NEEDED
from sklearn.model_selection import cross_val_predict
fig,ax = plt.subplots()
predicted = cross_val_predict(grid_search,X_train,y_train, cv=kfold)
ax.scatter(y_train, predicted)
predicted = cross_val_predict(grid_search,X_test,y_test, cv=kfold)
ax.scatter(y_test, predicted)
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
fig.show()
# Out:
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # This is added back by InteractiveShellApp.init_path()

# %%
model_results.loc[len(model_results)]=[2,'Linear Regression',' N/A',linear_train,linear_test]
model_results
# Out:
#   S.No         Model_Name          Parameters  Train_Score  Test_Score
# 0    1     KNN Regression  {'n_neighbors': 2}     0.938982    0.806483
# 1    2  Linear Regression                 N/A     0.878416    0.861596

# %% [markdown]
# # Ridge

# %%
from  sklearn.linear_model import Ridge

x_range = [0.01, 0.1, 1, 10, 100]
train_score_list = []
test_score_list = []

for alpha in x_range: 
    ridge = Ridge(alpha)
    ridge.fit(X_train,y_train)
    train_score_list.append(ridge.score(X_train,y_train))
    test_score_list.append(ridge.score(X_test, y_test))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(x_range, train_score_list, c = 'g', label = 'Train Score')
plt.plot(x_range, test_score_list, c = 'b', label = 'Test Score')
plt.xscale('log')
plt.legend(loc = 3)
plt.xlabel(r'$\alpha$')
# Out:
# Text(0.5, 0, '$\\alpha$')

# %%
print(train_score_list)
print(test_score_list)
# Out:
# [0.8784143479746023, 0.8783291041015112, 0.8760279907029414, 0.8438373522577371, 0.5858964312612338]
# [0.8616420829507255, 0.8619895401722875, 0.8631070051546904, 0.8327240584231084, 0.5493182627167966]

# %%
#as for every value of alpha the test and train scores are almost similar....Lets as choose alpha = 0.1 for CV
ridge = Ridge(0.1)

scores = cross_val_score(ridge, X_train, y_train)
print("Cross-validation train_scores: {}".format(scores))
print("Average cross-validation train_scores: {:.2f}".format(scores.mean()))

scores = cross_val_score(ridge, X_test, y_test)
print("Cross-validation test_scores: {}".format(scores))
print("Average cross-validation train_scores: {:.2f}".format(scores.mean()))
# Out:
# Cross-validation train_scores: [0.89936398 0.85742296 0.86244715]
# Average cross-validation train_scores: 0.87
# Cross-validation test_scores: [0.87076015 0.86834462 0.84654479]
# Average cross-validation train_scores: 0.86
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
param_grid = {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}
print("Parameter grid:\n{}".format(param_grid))

from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(Ridge(), param_grid, cv=5, return_train_score=True)
grid_search.fit(X_train, y_train)
print("Best parameters: {}".format(grid_search.best_params_))
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))
# Out:
# Parameter grid:
# {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}
# Best parameters: {'alpha': 0.01}
# Best cross-validation score: 0.87

# %%
ridge = Ridge(alpha = 1)
ridge.fit(X_train,y_train)
print('Train score: {:.4f}'.format(ridge.score(X_train,y_train)))
print('Test score: {:.4f}'.format(ridge.score(X_test, y_test)))
# Out:
# Train score: 0.8760
# Test score: 0.8631

# %%
ridge = Ridge(alpha = 100)
ridge.fit(X_train,y_train)
print('Train score: {:.4f}'.format(ridge.score(X_train,y_train)))
print('Test score: {:.4f}'.format(ridge.score(X_test, y_test)))
# Out:
# Train score: 0.5859
# Test score: 0.5493

# %%
ridge = Ridge(alpha = 0.01)
ridge.fit(X_train,y_train)
print('Train score: {:.4f}'.format(ridge.score(X_train,y_train)))
print('Test score: {:.4f}'.format(ridge.score(X_test, y_test)))
test_score = '{:.4f}'.format(ridge.score(X_test, y_test))
# Out:
# Train score: 0.8784
# Test score: 0.8616

# %% [markdown]
# alpha = 0.01 gives the best value

# %%
ridge.coef_
# Out:
# array([  4198.57803661,  19401.76242909,  -4564.87805454,  72598.67363466,
#         -1878.97541214,  -1126.56798283,  -2212.81147135,   2628.72272103,
#          3369.14486806,  -4527.82716398,  -4232.60941356,  20749.98911756,
#        -19887.24855585])

# %%
ridge.intercept_
# Out:
# -5010.535074353338

# %%
# %matplotlib inline
import numpy as np

x_range1 = np.linspace(0.001, 1, 100).reshape(-1,1)
x_range2 = np.linspace(1, 10000, 10000).reshape(-1,1)

x_range = np.append(x_range1, x_range2)
coeff = []

for alpha in x_range: 
    ridge = Ridge(alpha)
    ridge.fit(X_train,y_train)
    coeff.append(ridge.coef_ )
    
coeff = np.array(coeff)

for i in range(0,13):
    plt.plot(x_range, coeff[:,i], label = 'feature {:d}'.format(i))

plt.axhline(y=0, xmin=0.001, xmax=9999, linewidth=1, c ='gray')
plt.xlabel(r'$\alpha$')
plt.xscale('log')
plt.legend(loc='upper', bbox_to_anchor=(1, 1.5),
          ncol=3, fancybox=True, shadow=True)
plt.show()
# Out:
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: MatplotlibDeprecationWarning: Unrecognized location 'upper'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
model_results.loc[len(model_results)]=[3,'Ridge Regression',grid_search.best_params_,grid_search.best_score_,test_score]
model_results
# Out:
#   S.No         Model_Name          Parameters  Train_Score Test_Score
# 0    1     KNN Regression  {'n_neighbors': 2}     0.938982   0.806483
# 1    2  Linear Regression                 N/A     0.878416   0.861596
# 2    3   Ridge Regression     {'alpha': 0.01}     0.872944     0.8616

# %% [markdown]
# # Lasso

# %%
from sklearn.linear_model import Lasso
x_range = [0.01, 0.1, 1, 10]
train_score_list = []
test_score_list = []

for alpha in x_range:
    lasso = Lasso(alpha)
    lasso.fit(X_train, y_train)
    train_score_list.append(lasso.score(X_train, y_train))
    test_score_list.append(lasso.score(X_test, y_test))

# %%
train_score_list
# Out:
# [0.8784156180643702,
#  0.8784154123902421,
#  0.8783949283675038,
#  0.8773123911219589]

# %%
test_score_list
# Out:
# [0.8615967343629689,
#  0.8615990475779264,
#  0.8616076987048057,
#  0.8611653224425798]

# %%
y_axis = range (0,1)
plt.plot(x_range, train_score_list, c = 'g', label = 'Train score')
plt.plot(x_range, test_score_list, c = 'b', label = 'Test score')
plt.xscale('log')
plt.legend(loc = 3)
plt.xlabel(r'$\alpha$')
# Out:
# Text(0.5, 0, '$\\alpha$')

# %%
param_grid = {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}
print("Parameter grid:\n{}".format(param_grid))

from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(Lasso(), param_grid, cv=5, return_train_score=True)
grid_search.fit(X_train, y_train)
print("Best parameters: {}".format(grid_search.best_params_))
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))
# Out:
# Parameter grid:
# {'alpha': [0.001, 0.01, 0.1, 1, 10, 100]}
# Best parameters: {'alpha': 0.001}
# Best cross-validation score: 0.87

# %%
lasso = Lasso(alpha = 0.001)
lasso.fit(X_train,y_train)
print('Train score: {:.4f}'.format(lasso.score(X_train,y_train)))
print('Test score: {:.4f}'.format(lasso.score(X_test, y_test)))
# Out:
# Train score: 0.8784
# Test score: 0.8616

# %%
# %matplotlib inline

x_range1 = np.linspace(0.001, 1, 1000).reshape(-1,1)
x_range2 = np.linspace(1, 1000, 1000).reshape(-1,1)

x_range = np.append(x_range1, x_range2)
coeff = []

for alpha in x_range: 
    lasso = Lasso(alpha)
    lasso.fit(X_train,y_train)
    coeff.append(lasso.coef_ )
    
coeff = np.array(coeff)

for i in range(0,13):
    plt.plot(x_range, coeff[:,i], label = 'feature {:d}'.format(i))

plt.axhline(y=0, xmin=0.001, xmax=9999, linewidth=1, c ='gray')
plt.xlabel(r'$\alpha$')
plt.xscale('log')
plt.legend(loc='upper', bbox_to_anchor=(1, 1.5),
          ncol=3, fancybox=True, shadow=True)
plt.show()
# Out:
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: MatplotlibDeprecationWarning: Unrecognized location 'upper'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.

# %%
model_results.loc[len(model_results)]=[4,'Lasso Regression',grid_search.best_params_,grid_search.best_score_,test_score]
model_results
# Out:
#   S.No         Model_Name          Parameters  Train_Score Test_Score
# 0    1     KNN Regression  {'n_neighbors': 2}     0.938982   0.806483
# 1    2  Linear Regression                 N/A     0.878416   0.861596
# 2    3   Ridge Regression     {'alpha': 0.01}     0.872944     0.8616
# 3    4   Lasso Regression    {'alpha': 0.001}     0.872942     0.8616

# %% [markdown]
# # Polynomial regression

# %%
from  sklearn.preprocessing  import PolynomialFeatures
train_score_list = []
test_score_list = []

for n in range(1,5):
    poly = PolynomialFeatures(n)
    X_train_poly = poly.fit_transform(X_train)
    X_test_poly = poly.transform(X_test)
    lreg.fit(X_train_poly, y_train)
    train_score_list.append(lreg.score(X_train_poly, y_train))
    test_score_list.append(lreg.score(X_test_poly, y_test))

# %%
print(train_score_list)
print(test_score_list)
# Out:
# [0.8784156201461062, 0.9678538777222463, 0.9874956660090395, 0.9867948234093475]
# [0.8615964616962233, 0.9201837973735152, -1.2403770027300912e+16, -3.9270022920132146e+20]

# %% [markdown]
# We get best scores with polynomial regression of order 2

# %%
print("Train Score",train_score_list[1])
print("Test Score",test_score_list[1])
print("Best Parameters n=",2)
# Out:
# Train Score 0.9678538777222463
# Test Score 0.9201837973735152
# Best Parameters n= 2

# %%
# %matplotlib inline

x_axis = range(1,5)
plt.plot(x_axis, train_score_list, c = 'g', label = 'Train Score')
plt.plot(x_axis, test_score_list, c = 'b', label = 'Test Score')
plt.xlabel('degree')
plt.ylabel('accuracy')
plt.legend()

# %%
from sklearn.model_selection import cross_val_predict
fig,ax = plt.subplots()
predicted = cross_val_predict(grid_search,X_train,y_train, cv=kfold)
ax.scatter(y_train, predicted)
predicted1 = cross_val_predict(grid_search,X_test,y_test, cv=kfold)
ax.scatter(y_test, predicted1)
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
fig.show()
# Out:
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %%
model_results.loc[len(model_results)]=[5,'Polynomial Regression',"{'degree': 2}",train_score_list[1],test_score_list[1]]
model_results
# Out:
#   S.No             Model_Name          Parameters  Train_Score Test_Score
# 0    1         KNN Regression  {'n_neighbors': 2}     0.938982   0.806483
# 1    2      Linear Regression                 N/A     0.878416   0.861596
# 2    3       Ridge Regression     {'alpha': 0.01}     0.872944     0.8616
# 3    4       Lasso Regression    {'alpha': 0.001}     0.872942     0.8616
# 4    5  Polynomial Regression       {'degree': 2}     0.967854   0.920184

# %% [markdown]
# # Linear SVM

# %%
from sklearn.svm import LinearSVR
from sklearn.model_selection import GridSearchCV
kfold =KFold(n_splits=2, random_state=0)

param_grid = {'C': [0.001, 0.01, 0.1, 1, 0.5, 10, 100], 'max_iter':[50000]}
grid_search = GridSearchCV(LinearSVR(), param_grid, cv=kfold, return_train_score=True)

grid_search.fit(X_train, y_train)

test=cross_val_score(grid_search,X_test, y_test,scoring='r2',cv=kfold).mean()
# Out:
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)

# %%
print("Train set score with best parameters: {:.5f}".format(grid_search.best_score_))
print("Test set score with best parameters: {:.5f}".format(test))
print("best parameters are:",grid_search.best_params_)
# Out:
# Train set score with best parameters: 0.30491
# Test set score with best parameters: -0.07296
# best parameters are: {'C': 100, 'max_iter': 50000}

# %%
from sklearn.model_selection import cross_val_predict
fig,ax = plt.subplots()
predicted = cross_val_predict(grid_search,X_train,y_train, cv=kfold)
ax.scatter(y_train, predicted)
predicted = cross_val_predict(grid_search,X_test,y_test, cv=kfold)
ax.scatter(y_test, predicted)
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
fig.show()
# Out:
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %%
model_results.loc[len(model_results)]=[6,'Linear SVM',grid_search.best_params_,'{:.5f}'.format(grid_search.best_score_),'{:.5f}'.format(test)]
model_results
# Out:
#   S.No             Model_Name                     Parameters Train_Score  \
# 0    1         KNN Regression             {'n_neighbors': 2}    0.938982
# 1    2      Linear Regression                            N/A    0.878416
# 2    3       Ridge Regression                {'alpha': 0.01}    0.872944
# 3    4       Lasso Regression               {'alpha': 0.001}    0.872942
# 4    5  Polynomial Regression                  {'degree': 2}    0.967854
# 5    6             Linear SVM  {'C': 100, 'max_iter': 50000}     0.30491
#
#   Test_Score
# 0   0.806483
# 1   0.861596
# 2     0.8616
# 3     0.8616
# 4   0.920184
# 5   -0.07296

# %% [markdown]
# ## SVM with RBF Kernel

# %%
from sklearn.svm import SVR
svr_kernel = SVR( kernel = "rbf")
svr_kernel.fit(X_train,y_train)

x_range = [0.01, 0.1, 1, 10, 100]
train_score_list = []
test_score_list = []

for gamma in x_range: 
    svr_kernel = SVR(gamma = gamma, kernel = "rbf")
    svr_kernel.fit(X_train,y_train)
    train_score_list.append(svr_kernel.score(X_train,y_train))
    test_score_list.append(svr_kernel.score(X_test, y_test))
# Out:
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100],
              'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}
print("Parameter grid:\n{}".format(param_grid))

from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(SVR(), param_grid, cv=5, return_train_score=True)
grid_search.fit(X_train, y_train)
print("Best parameters: {}".format(grid_search.best_params_))
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))
# Out:
# Parameter grid:
# {'C': [0.001, 0.01, 0.1, 1, 10, 100], 'gamma': [0.001, 0.01, 0.1, 1, 10, 100]}
# Best parameters: {'C': 100, 'gamma': 1}
# Best cross-validation score: 0.21

# %%
print("Train set score with best parameters: {:.5f}".format(grid_search.best_score_))
print("Test set score with best parameters: {:.5f}".format(test))
print("best parameters are:",grid_search.best_params_)
# Out:
# Train set score with best parameters: 0.21434
# Test set score with best parameters: -0.07296
# best parameters are: {'C': 100, 'gamma': 1}

# %%
svr_kernel = SVR(gamma = 1,C = 100 , kernel = "rbf")

#CV
scores = cross_val_score(svr_kernel, X_train, y_train)
print("Cross-validation train_scores: {}".format(scores))
print("Average cross-validation train_scores: {:.2f}".format(scores.mean()))

scores = cross_val_score(svr_kernel, X_test, y_test)
print("Cross-validation test_scores: {}".format(scores))
print("Average cross-validation train_scores: {:.2f}".format(scores.mean()))
# Out:
# Cross-validation train_scores: [0.16861311 0.17894912 0.20409079]
# Average cross-validation train_scores: 0.18
# Cross-validation test_scores: [ 0.03369163  0.01894831 -0.01744456]
# Average cross-validation train_scores: 0.01
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)

# %%
x_range = [0.01, 0.1, 1, 10, 100]
train_score_list = []
test_score_list = []

for gamma in x_range: 
    svr_kernel = SVR(gamma = 1,C = gamma , kernel = "rbf")
    svr_kernel.fit(X_train,y_train)
    train_score_list.append(svr_kernel.score(X_train,y_train))
    test_score_list.append(svr_kernel.score(X_test, y_test))

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(x_range, train_score_list, c = 'g', label = 'Train Score')
plt.plot(x_range, test_score_list, c = 'b', label = 'Test Score')
plt.xscale('log')
plt.legend(loc = 3)

# %%
model_results.loc[len(model_results)]=[7,'SVM with RBF Kernel',grid_search.best_params_,'{:.5f}'.format(grid_search.best_score_),'{:.5f}'.format(test)]
model_results
# Out:
#   S.No             Model_Name                     Parameters Train_Score  \
# 0    1         KNN Regression             {'n_neighbors': 2}    0.938982
# 1    2      Linear Regression                            N/A    0.878416
# 2    3       Ridge Regression                {'alpha': 0.01}    0.872944
# 3    4       Lasso Regression               {'alpha': 0.001}    0.872942
# 4    5  Polynomial Regression                  {'degree': 2}    0.967854
# 5    6             Linear SVM  {'C': 100, 'max_iter': 50000}     0.30491
# 6    7    SVM with RBF Kernel         {'C': 100, 'gamma': 1}     0.21434
#
#   Test_Score
# 0   0.806483
# 1   0.861596
# 2     0.8616
# 3     0.8616
# 4   0.920184
# 5   -0.07296
# 6   -0.07296

# %% [markdown]
# # SVM with Linear Kernel

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
kfold =KFold(n_splits=5, random_state=0)
param_grid = {'C': [0.001, 0.01, 0.1, 1, 250, 10, 100], 'max_iter':[60000]}
grid_search = GridSearchCV(SVR(kernel='linear'), param_grid, cv=kfold, return_train_score=True)

grid_search.fit(X_train, y_train)

test=cross_val_score(grid_search,X_test, y_test,scoring='r2',cv=kfold).mean()
train=cross_val_score(grid_search,X_train, y_train,scoring='r2',cv=kfold).mean()

# %%
print("Train set score with best parameters: {:.5f}".format(grid_search.best_score_))
print("Test set score with best parameters: {:.5f}".format(test))
print("best parameters are:",grid_search.best_params_)
# Out:
# Train set score with best parameters: 0.59077
# Test set score with best parameters: 0.19325
# best parameters are: {'C': 250, 'max_iter': 60000}

# %%
model_results.loc[len(model_results)]=[8,'SVM with Linear Kernel',grid_search.best_params_,grid_search.best_score_,test]
model_results
# Out:
#   S.No              Model_Name                     Parameters Train_Score  \
# 0    1          KNN Regression             {'n_neighbors': 2}    0.938982
# 1    2       Linear Regression                            N/A    0.878416
# 2    3        Ridge Regression                {'alpha': 0.01}    0.872944
# 3    4        Lasso Regression               {'alpha': 0.001}    0.872942
# 4    5   Polynomial Regression                  {'degree': 2}    0.967854
# 5    6              Linear SVM  {'C': 100, 'max_iter': 50000}     0.30491
# 6    7     SVM with RBF Kernel         {'C': 100, 'gamma': 1}     0.21434
# 7    8  SVM with Linear Kernel  {'C': 250, 'max_iter': 60000}    0.590774
#
#   Test_Score
# 0   0.806483
# 1   0.861596
# 2     0.8616
# 3     0.8616
# 4   0.920184
# 5   -0.07296
# 6   -0.07296
# 7   0.193252

# %% [markdown]
# # SVM with Poly Kernel

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV
kfold =KFold(n_splits=5, random_state=0)
param_grid = {'C': [0.01, 10, 0.1, 1, 250, 100, 500],'degree':[1,2,3,4]}
grid_search = GridSearchCV(SVR(kernel='poly'), param_grid, cv=kfold, return_train_score=True);

grid_search.fit(X_train, y_train)

test=cross_val_score(grid_search,X_test, y_test,scoring='r2',cv=kfold).mean();
train=cross_val_score(grid_search,X_train, y_train,scoring='r2',cv=kfold).mean();
# Out:
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ...
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
print("Train set score with best parameters: {:.5f}".format(train))
print("Test set score with best parameters: {:.5f}".format(test))
print("best parameters are:",grid_search.best_params_)
# Out:
# Train set score with best parameters: 0.19506
# Test set score with best parameters: -0.01126
# best parameters are: {'C': 500, 'degree': 1}

# %%
model_results.loc[len(model_results)]=[9,'SVM with Poly Kernel',grid_search.best_params_,train,test]
model_results
# Out:
#   S.No              Model_Name                     Parameters Train_Score  \
# 0    1          KNN Regression             {'n_neighbors': 2}    0.938982
# 1    2       Linear Regression                            N/A    0.878416
# 2    3        Ridge Regression                {'alpha': 0.01}    0.872944
# 3    4        Lasso Regression               {'alpha': 0.001}    0.872942
# 4    5   Polynomial Regression                  {'degree': 2}    0.967854
# 5    6              Linear SVM  {'C': 100, 'max_iter': 50000}     0.30491
# 6    7     SVM with RBF Kernel         {'C': 100, 'gamma': 1}     0.21434
# 7    8  SVM with Linear Kernel  {'C': 250, 'max_iter': 60000}    0.590774
# 8    9    SVM with Poly Kernel        {'C': 500, 'degree': 1}    0.195063
#
#   Test_Score
# 0   0.806483
# 1   0.861596
# 2     0.8616
# 3     0.8616
# 4   0.920184
# 5   -0.07296
# 6   -0.07296
# 7   0.193252
# 8 -0.0112606

# %% [markdown]
# # Conclusion

# %% [markdown]
# From the above table, we chose Polynomial Regression with degree 2 as the best model as it has high train and test scores

# %% [markdown]
# Training the data with Polynomial Regression and predicting the unseen test data.

# %% [markdown]
# Predicting the MSRP of the Chevrolet car models

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_error

model = make_pipeline(PolynomialFeatures(2),Ridge())
model.fit(X_train,y_train)
y_predict = model.predict(X_test)
y_predict
# Out:
# array([35066.31696736, 35837.1516848 , 21929.50448589, 40827.15308643,
#        21728.41529056,  4101.86807328, 24605.95781233, 44196.8041633 ,
#        23894.04673504,  3958.60345082, 49741.30946619, 30346.26746718,
#        31137.67091905, 31636.57054408, 36405.26537883, 21142.82278072,
#        26028.07645575, 24591.27249491,  3246.82485362, 16072.76824748,
#        14837.7155018 , 33801.41755892, 25811.07869816, 38927.80817591,
#        10748.05535452, 17962.23356295, 24950.02858359, 46625.50123974,
#        28210.44210592, 45414.67910515, 17448.29393263, 25824.62779081,
#        18697.09175993, 46614.27959836, 24737.04672719, 21788.8663516 ,
#        34841.97651605, 24488.25616396,  1935.36143483, 17834.25504938,
#        60856.24466786,  1466.89738896, 13426.17960186, 23894.04673504,
#        13981.35376614, 35751.46466479, 28785.78308197, 21453.08887256,
#        30104.85317396, 63842.2833482 , 16895.75488188, 34638.98965732,
#        19379.58021468, 16895.75488188, 67075.71280972, 83690.82138992,
#        25562.4061986 , 39644.22517241, 21785.45059599, 36405.26537883,
#        20800.67529543, 28007.13886328, 31137.67091905, 20646.20859372,
#        25562.4061986 , 54389.11723406, 53923.47125617, 25489.77769141,
#        46306.34820676, 27777.75460437, 31137.67091905, 12945.67867831,
#        21231.73577727, 25727.26733049, 19051.61982792, 30509.00971048,
#        39644.22517241, 18697.09175993, 36577.45716954, 37191.80676315,
#        44196.8041633 , 32906.96604108, 20800.67529543, 52781.84767788,
#        13381.86197323, 19615.04232204, 22347.11050078, 19208.50434752,
#        37076.86054823, 45414.67910515, 45414.67910515, 22267.64227492,
#        31991.80299673, 44196.8041633 , 19645.50646955, 42989.15258379,
#        33801.41755892, 24819.09053525, 24591.27249491,  2936.20011597,
#        22190.48541233, 20646.20859372, 25466.06664511, 24912.23146633,
#         4143.84164913, 61387.90785018, 41693.47588618, 52177.39951236,
#         4290.69396696, 19839.2567156 , 34132.61018315, 39140.69428406,
#        21626.23246276,  2594.12385672, 44073.9061264 , 30100.18477881,
#        19192.94591526,  5219.94708355, 18866.48708941, 33613.39794201,
#        39693.24313355, 18733.89691803, 53856.39383662, 23238.68839482,
#        14281.14779455, 36405.26537883,   232.83191406,  9295.58652805,
#        19051.61982792, 46469.50371302, 24687.9761827 , 67637.55813696,
#         2972.19646607, 32372.02049907, 20701.19628234, 41062.25597249,
#        37191.80676315, 64868.50650246, 35299.25245762, 19636.48955669,
#        27394.34987237, 59524.45538597, 24737.04672719, 39641.04740915,
#        50402.96621461, 22115.53863788, 15428.3988237 , 31113.34981753,
#        15072.84762043, 35668.09622308, 16125.37776596, 56133.83711614,
#         5114.19241312, 40767.35249048, 23793.4063043 , 47639.33481153,
#         3905.27171359, 40944.25837037, 20033.16611258, 53923.47125617,
#        15970.45239738, 18856.92796374, 67075.71280972, 33145.50642231,
#        35678.76262928, 24220.72039833, 16635.26779273, 14057.19518374,
#        33647.58998731, 28302.72186876, 24075.71981958, 28531.43840021,
#        25466.06664511, 33393.8212122 , 17518.43451965, 30586.04334689,
#        19809.03796729, 19644.40316302, 42468.67687458, 81073.06120408,
#        41636.07326039, 22802.41991316, 18491.40234373, 27408.42813866,
#        18857.20851355, 18799.04715599, 38927.80817591, 30874.14282031,
#         3895.98775502, 27173.48683539, 38728.13619048, 21785.45059599,
#        32031.45570438,  4595.68008034, 24075.71981958, 18819.61078546,
#        18337.04747154, 36793.41081305,  8273.88077291, 31137.67091905,
#         2651.09000808, 38150.66379473, 23998.24914173, 40440.40364257,
#        22728.73340265, 22821.37802656, 84342.21590602, 18410.33296885,
#        43343.69881989, 67637.55813696, 16699.46141355, 29064.44261289,
#        45330.09861991, 23989.33757103, 31228.33186023, 17920.5606512 ,
#        31228.33186023, 22940.23936986, 62753.81209374, 32031.45570438,
#        24143.98502873, 39808.97436911, 45414.67910515, 18026.91735197,
#        24950.02858359])

# %% [markdown]
# Actual MSRP of the Chevrolet car models

# %%
y_test
# Out:
# 1040    42145
# 922     39240
# 395     21920
# 1016    34290
# 511     23465
#         ...
# 474     29310
# 1027    37195
# 785     43260
# 386     19065
# 418     25210
# Name: MSRP, Length: 225, dtype: int64

# %% [markdown]
# Plotting Actual MSRP Vs Predicted MSRP using the model

# %%
from sklearn.model_selection import cross_val_predict
fig,ax = plt.subplots()
#predicted = cross_val_predict(grid_search,X_test,y_test, cv=kfold)
ax.scatter(y_test, predicted1)
ax.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4)
ax.set_xlabel('Measured')
ax.set_ylabel('Predicted')
fig.show()
# Out:
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# # Bagging with Linear SVM

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import BaggingRegressor
lreg = LinearRegression()
bag_rgr = BaggingRegressor(lreg, n_estimators=1000, max_samples=800, bootstrap=True, random_state=0)
bag_rgr.fit(X_train, y_train)
bag_rgr.score(X_test, y_test)
print('Train score: {:.2f}'.format(bag_rgr.score(X_train, y_train)))
print('Test score: {:.2f}'.format(bag_rgr.score(X_test, y_test)))
# Out:
# Train score: 0.88
# Test score: 0.86

# %% [markdown]
# # Bagging with K Neighbors Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor

knn_reg = KNeighborsRegressor()
bag_rgr = BaggingRegressor(knn_reg, n_estimators=1000, max_samples=800, bootstrap=True, random_state=0)
bag_rgr.fit(X_train, y_train)
bag_rgr.score(X_test, y_test)

print('Train score: {:.2f}'.format(bag_rgr.score(X_train, y_train)))
print('Test score: {:.2f}'.format(bag_rgr.score(X_test, y_test)))
# Out:
# Train score: 0.96
# Test score: 0.90

# %% [markdown]
# # Pasting with linear regressor

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import BaggingRegressor

lreg = LinearRegression()
bag_rgr = BaggingRegressor(lreg, n_estimators=1000, max_samples=800, bootstrap=False, random_state=0)

bag_rgr.fit(X_train, y_train)
bag_rgr.score(X_test, y_test)

print('Train score: {:.2f}'.format(bag_rgr.score(X_train, y_train)))
print('Test score: {:.2f}'.format(bag_rgr.score(X_test, y_test)))
# Out:
# Train score: 0.88
# Test score: 0.86

# %% [markdown]
# # Pasting with K Neighbors Regressor

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor

knn_reg = KNeighborsRegressor()
bag_rgr = BaggingRegressor(knn_reg, n_estimators=1000, max_samples=800, bootstrap=False, random_state=0)
bag_rgr.fit(X_train, y_train)
bag_rgr.score(X_test, y_test)


print('Train score: {:.2f}'.format(bag_rgr.score(X_train, y_train)))
print('Test score: {:.2f}'.format(bag_rgr.score(X_test, y_test)))
# Out:
# Train score: 0.96
# Test score: 0.89

# %% [markdown]
# # ADA Boost using K Neighbors Regressor

# %%
from sklearn.model_selection import train_test_split

X_train_org, X_test_org, y_train, y_test = train_test_split(X,y, random_state = 0)

scaler = StandardScaler()
scaler.fit(X_train_org)
X_train = scaler.transform(X_train_org)
X_test = scaler.transform(X_test_org)

knn_reg = KNeighborsRegressor()

from sklearn.ensemble import AdaBoostRegressor

ada_clf = AdaBoostRegressor(knn_reg, n_estimators=200, learning_rate=0.5, random_state=0)
ada_clf.fit(X_train, y_train)
ada_clf.score(X_test, y_test)

print('Train score: {:.2f}'.format(ada_clf.score(X_train, y_train)))
print('Test score: {:.2f}'.format(ada_clf.score(X_test, y_test)))
# Out:
# Train score: 0.95
# Test score: 0.93

# %% [markdown]
# # ADA boost using Ridge

# %%
from sklearn.model_selection import train_test_split

X_train_org, X_test_org, y_train, y_test = train_test_split(X,y, random_state = 0)

scaler = StandardScaler()
scaler.fit(X_train_org)
X_train = scaler.transform(X_train_org)
X_test = scaler.transform(X_test_org)

from  sklearn.linear_model import Ridge
ridge = Ridge()

from sklearn.ensemble import AdaBoostRegressor

ada_clf = AdaBoostRegressor(ridge, n_estimators=200, learning_rate=0.5, random_state=0)
ada_clf.fit(X_train, y_train)
ada_clf.score(X_test, y_test)

print('Train score: {:.2f}'.format(ada_clf.score(X_train, y_train)))
print('Test score: {:.2f}'.format(ada_clf.score(X_test, y_test)))
# Out:
# Train score: 0.87
# Test score: 0.88

# %% [markdown]
# # Gradient boosting on K Neighbour Regressor

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train_org, X_test_org, y_train, y_test = train_test_split(X, y, random_state = 42)
scaler = StandardScaler()
scaler.fit(X_train_org)
X_train = scaler.transform(X_train_org)
X_test = scaler.transform(X_test_org)

from  sklearn.ensemble import GradientBoostingRegressor

gbrt = GradientBoostingRegressor(random_state=0)
gbrt.fit(X_train, y_train)

print("Accuracy on training set: {:.3f}".format(gbrt.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(gbrt.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.979
# Accuracy on test set: 0.970

# %%
gbrt = GradientBoostingRegressor(random_state=0, max_depth=3, learning_rate=0.1 , n_estimators=100)
gbrt.fit(X_train, y_train)

print("Accuracy on training set: {:.3f}".format(gbrt.score(X_train, y_train)))
print("Accuracy on test set: {:.3f}".format(gbrt.score(X_test, y_test)))
# Out:
# Accuracy on training set: 0.979
# Accuracy on test set: 0.970

# %% [markdown]
# # PCA

# %%
X.shape
# Out:
# (1123, 13)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components= 0.95)
pca.fit(X_train)
X_train_reduced = pca.transform(X_train)

# %%
X_train_reduced.shape
# Out:
# (842, 10)

# %%
X_test_reduced = pca.transform(X_test)

# %% [markdown]
# # PCA with K Neighbour Regressor

# %%
knn_reg.fit(X_train_reduced, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform')

# %%
print('Train score: ', knn_reg.score(X_train_reduced, y_train))
print('Test score: ', knn_reg.score(X_test_reduced, y_test))
# Out:
# Train score:  0.9601604761511628
# Test score:  0.9426597415098794

# %%
PCA_results = pd.DataFrame(columns=('S.No','Model_Name','Train_score','Test_Score'))

# %%
PCA_results.loc[len(PCA_results)]=[1,'PCA - Knn',knn_reg.score(X_train_reduced, y_train),knn_reg.score(X_test_reduced, y_test)]

# %%
PCA_results
# Out:
#   S.No Model_Name  Train_score  Test_Score
# 0    1  PCA - Knn      0.96016     0.94266

# %% [markdown]
# # PCA with linear regressor

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components= 0.95)
pca.fit(X_train)
X_train_reduced = pca.transform(X_train)

# %%
X_train_reduced.shape
# Out:
# (842, 10)

# %%
lreg.fit(X_train_reduced, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Train score: ', lreg.score(X_train_reduced, y_train))
print('Test score: ', lreg.score(X_test_reduced, y_test))
# Out:
# Train score:  0.8569551774374475
# Test score:  0.8560862049471138

# %%
PCA_results.loc[len(PCA_results)]=[2,'PCA -Linear regressor',lreg.score(X_train_reduced, y_train),lreg.score(X_test_reduced, y_test)]

# %%
PCA_results
# Out:
#   S.No             Model_Name  Train_score  Test_Score
# 0    1              PCA - Knn     0.960160    0.942660
# 1    2  PCA -Linear regressor     0.856955    0.856086

# %% [markdown]
# # PCA with Polynomial Regression

# %%
train_score_list = []
test_score_list = []

for n in range(1,5):
    poly = PolynomialFeatures(n)
    X_train_poly = poly.fit_transform(X_train)
    X_test_poly = poly.transform(X_test)
    lreg.fit(X_train_poly, y_train)
    train_score_list.append(lreg.score(X_train_poly, y_train))
    test_score_list.append(lreg.score(X_test_poly, y_test))

# %%
print(train_score_list)
print(test_score_list)
# Out:
# [0.877519007323857, 0.9628333607944626, 0.9875053274026538, 0.9877014882910363]
# [0.8695172965102818, 0.9519480599814522, -1089123.3033062331, -2743.9807461923288]

# %%
print("Train Score",train_score_list[1])
print("Test Score",test_score_list[1])
print("Best Parameters n=",2)
# Out:
# Train Score 0.9628333607944626
# Test Score 0.9519480599814522
# Best Parameters n= 2

# %%
PCA_results.loc[len(PCA_results)]=[3,' PCA - Polynomial Regression',train_score_list[1], test_score_list[1]]
PCA_results
# Out:
#   S.No                    Model_Name  Train_score  Test_Score
# 0    1                     PCA - Knn     0.960160    0.942660
# 1    2         PCA -Linear regressor     0.856955    0.856086
# 2    3   PCA - Polynomial Regression     0.962833    0.951948

# %% [markdown]
# # PCA with ridge

# %%
ridge.fit(X_train_reduced, y_train)
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
print('Train score: ', ridge.score(X_train_reduced, y_train))
print('Test score: ', ridge.score(X_test_reduced, y_test))
# Out:
# Train score:  0.856954658899214
# Test score:  0.8560953886104675

# %%
PCA_results.loc[len(PCA_results)]=[4,'Ridge',ridge.score(X_train_reduced, y_train),ridge.score(X_test_reduced, y_test)]
PCA_results
# Out:
#   S.No                    Model_Name  Train_score  Test_Score
# 0    1                     PCA - Knn     0.960160    0.942660
# 1    2         PCA -Linear regressor     0.856955    0.856086
# 2    3   PCA - Polynomial Regression     0.962833    0.951948
# 3    4                         Ridge     0.856955    0.856095

# %% [markdown]
# # PCA with Lasso

# %%
lasso.fit(X_train_reduced, y_train)
# Out:
# Lasso(alpha=1000.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
print('Train score: ', lasso.score(X_train_reduced, y_train))
print('Test score: ', lasso.score(X_test_reduced, y_test))
# Out:
# Train score:  0.8269139563818502
# Test score:  0.8265651453584819

# %%
PCA_results.loc[len(PCA_results)]=[5,'Lasso',lasso.score(X_train_reduced, y_train),lasso.score(X_test_reduced, y_test)]
PCA_results
# Out:
#   S.No                    Model_Name  Train_score  Test_Score
# 0    1                     PCA - Knn     0.960160    0.942660
# 1    2         PCA -Linear regressor     0.856955    0.856086
# 2    3   PCA - Polynomial Regression     0.962833    0.951948
# 3    4                         Ridge     0.856955    0.856095
# 4    5                         Lasso     0.826914    0.826565

# %% [markdown]
# # PCA with Linear SVM

# %%
param_grid = {'C': [0.001, 0.01, 0.1, 1, 0.5, 10, 100], 'max_iter':[50000]}
grid_search = GridSearchCV(LinearSVR(), param_grid, cv=kfold, return_train_score=True)

grid_search.fit(X_train_reduced, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=0, shuffle=False),
#              error_score='raise-deprecating',
#              estimator=LinearSVR(C=1.0, dual=True, epsilon=0.0,
#                                  fit_intercept=True, intercept_scaling=1.0,
#                                  loss='epsilon_insensitive', max_iter=1000,
#                                  random_state=None, tol=0.0001, verbose=0),
#              iid='warn', n_jobs=None,
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 0.5, 10, 100],
#                          'max_iter': [50000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring=None, verbose=0)

# %%
print('Train score: ', grid_search.score(X_train_reduced, y_train))
print('Test score: ', grid_search.score(X_test_reduced, y_test))
# Out:
# Train score:  0.782498203520735
# Test score:  0.7799645301519453

# %%
PCA_results.loc[len(PCA_results)]=[6,'Linear SVM',grid_search.score(X_train_reduced, y_train),grid_search.score(X_test_reduced, y_test)]

# %%
PCA_results
# Out:
#   S.No                    Model_Name  Train_score  Test_Score
# 0    1                     PCA - Knn     0.960160    0.942660
# 1    2         PCA -Linear regressor     0.856955    0.856086
# 2    3   PCA - Polynomial Regression     0.962833    0.951948
# 3    4                         Ridge     0.856955    0.856095
# 4    5                         Lasso     0.826914    0.826565
# 5    6                    Linear SVM     0.782498    0.779965

# %% [markdown]
# # PCA with SVM RBF Kernel

# %%
svr_kernel.fit(X_train_reduced,y_train)
# Out:
# SVR(C=100, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma=1,
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
print('Train score: ', svr_kernel.score(X_train_reduced, y_train))
print('Test score: ', svr_kernel.score(X_test_reduced, y_test))
# Out:
# Train score:  0.0765319729107654
# Test score:  0.07620828873988494

# %%
PCA_results.loc[len(PCA_results)]=[7,'SVM RBF Kernel',svr_kernel.score(X_train_reduced, y_train),svr_kernel.score(X_test_reduced, y_test)]

# %%
PCA_results
# Out:
#   S.No                    Model_Name  Train_score  Test_Score
# 0    1                     PCA - Knn     0.960160    0.942660
# 1    2         PCA -Linear regressor     0.856955    0.856086
# 2    3   PCA - Polynomial Regression     0.962833    0.951948
# 3    4                         Ridge     0.856955    0.856095
# 4    5                         Lasso     0.826914    0.826565
# 5    6                    Linear SVM     0.782498    0.779965
# 6    7                SVM RBF Kernel     0.076532    0.076208

# %% [markdown]
# # PCA with SVM Linear Kernel

# %%
svr_kernel_linear = SVR( kernel = "linear")
svr_kernel_linear.fit(X_train_reduced,y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='linear', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print('Train score: ', svr_kernel_linear.score(X_train_reduced, y_train))
print('Test score: ', svr_kernel_linear.score(X_test_reduced, y_test))
# Out:
# Train score:  0.12056867586165909
# Test score:  0.11860878583693747

# %%
PCA_results.loc[len(PCA_results)]=[8,'SVM Linear Kernel',svr_kernel_linear.score(X_train_reduced, y_train),svr_kernel_linear.score(X_test_reduced, y_test)]

# %%
PCA_results
# Out:
#   S.No                    Model_Name  Train_score  Test_Score
# 0    1                     PCA - Knn     0.960160    0.942660
# 1    2         PCA -Linear regressor     0.856955    0.856086
# 2    3   PCA - Polynomial Regression     0.962833    0.951948
# 3    4                         Ridge     0.856955    0.856095
# 4    5                         Lasso     0.826914    0.826565
# 5    6                    Linear SVM     0.782498    0.779965
# 6    7                SVM RBF Kernel     0.076532    0.076208
# 7    8             SVM Linear Kernel     0.120569    0.118609

# %% [markdown]
# # PCA with SVM Poly Kernel

# %%
svr_kernel_poly = SVR( kernel = "poly")
svr_kernel_poly.fit(X_train_reduced,y_train)
# Out:
# C:\Users\Amritha_Rekha\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='poly', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
print('Train score: ', svr_kernel_poly.score(X_train_reduced, y_train))
print('Test score: ', svr_kernel_poly.score(X_test_reduced, y_test))
# Out:
# Train score:  -0.0031730688846742794
# Test score:  0.0006438384420884846

# %%
PCA_results.loc[len(PCA_results)]=[9,'SVM Poly Kernel',svr_kernel_poly.score(X_train_reduced, y_train),svr_kernel_poly.score(X_test_reduced, y_test)]

# %%
PCA_results
# Out:
#   S.No                    Model_Name  Train_score  Test_Score
# 0    1                     PCA - Knn     0.960160    0.942660
# 1    2         PCA -Linear regressor     0.856955    0.856086
# 2    3   PCA - Polynomial Regression     0.962833    0.951948
# 3    4                         Ridge     0.856955    0.856095
# 4    5                         Lasso     0.826914    0.826565
# 5    6                    Linear SVM     0.782498    0.779965
# 6    7                SVM RBF Kernel     0.076532    0.076208
# 7    8             SVM Linear Kernel     0.120569    0.118609
# 8    9               SVM Poly Kernel    -0.003173    0.000644

# %% [markdown]
# When tabular results of after PCA are compared to before PCA, we found that all the models have been improved in either the train or test score or both.
# Especially, we found that the best model from Project 1-Polynomial Regression has improved in its test score a little more after PCA.

# %% [markdown]
# # Deep-learning models.

# %%
X_train.shape
# Out:
# (842, 13)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
# %matplotlib inline
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from keras.optimizers import SGD
from keras.utils import np_utils

np.random.seed(0) # for reproducibility

# %% [markdown]
# ### 1. Perceptron

# %%
#step 1: build model
model1 = Sequential()
#input layer
model1.add(Dense(20, input_dim = 13, activation = 'relu'))
#hidden layers
#output layer
model1.add(Dense(1))

#step 2: make computational graph - compile
model1.compile(loss= 'mean_squared_error' , optimizer = 'adam',metrics = ['mean_squared_error'] )

#step 3: train the model - fit
model1.fit(X_train, y_train, epochs = 150, batch_size = 300);
# Out:
# Train on 842 samples
# Epoch 1/150
# 842/842 [==============================] - 0s 86us/sample - loss: 1113101285.8527 - mean_squared_error: 1113101312.0000
# Epoch 2/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1113098322.3943 - mean_squared_error: 1113098240.0000
# Epoch 3/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1113095259.5154 - mean_squared_error: 1113095296.0000
# Epoch 4/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1113092244.9786 - mean_squared_error: 1113092352.0000
# Epoch 5/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1113089109.7387 - mean_squared_error: 1113089152.0000
# Epoch 6/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1113085996.6936 - mean_squared_error: 1113085952.0000
# Epoch 7/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1113083072.3040 - mean_squared_error: 1113083136.0000
# Epoch 8/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1113080029.9477 - mean_squared_error: 1113080064.0000
# Epoch 9/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1113076891.3634 - mean_squared_error: 1113076864.0000
# Epoch 10/150
# 842/842 [==============================] - 0s 4us/sample - loss: 1113073678.5938 - mean_squared_error: 1113073664.0000
# Epoch 11/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1113070689.9002 - mean_squared_error: 1113070720.0000
# Epoch 12/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1113067552.8361 - mean_squared_error: 1113067520.0000
# Epoch 13/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1113064393.8812 - mean_squared_error: 1113064320.0000
# Epoch 14/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1113061175.3349 - mean_squared_error: 1113061120.0000
# Epoch 15/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1113057887.4679 - mean_squared_error: 1113057920.0000
# Epoch 16/150
# 842/842 [==============================] - 0s 4us/sample - loss: 1113054693.7007 - mean_squared_error: 1113054720.0000
# Epoch 17/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1113051439.5819 - mean_squared_error: 1113051392.0000
# Epoch 18/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1113047937.2162 - mean_squared_error: 1113048064.0000
# Epoch 19/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1113044669.1116 - mean_squared_error: 1113044608.0000
# Epoch 20/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1113041284.2565 - mean_squared_error: 1113041280.0000
# Epoch 21/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1113037776.8741 - mean_squared_error: 1113037696.0000
# Epoch 22/150
# 842/842 [==============================] - 0s 8us/sample - loss: 1113034302.6318 - mean_squared_error: 1113034368.0000
# Epoch 23/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1113030741.8907 - mean_squared_error: 1113030784.0000
# Epoch 24/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1113027078.6888 - mean_squared_error: 1113027200.0000
# Epoch 25/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1113023466.4133 - mean_squared_error: 1113023360.0000
# Epoch 26/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1113019619.1164 - mean_squared_error: 1113019648.0000
# Epoch 27/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1113015802.8314 - mean_squared_error: 1113015680.0000
# Epoch 28/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1113011895.0309 - mean_squared_error: 1113011840.0000
# Epoch 29/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1113007910.0048 - mean_squared_error: 1113007872.0000
# Epoch 30/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1113003933.1876 - mean_squared_error: 1113003904.0000
# Epoch 31/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112999805.5677 - mean_squared_error: 1112999808.0000
# Epoch 32/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112995521.9762 - mean_squared_error: 1112995584.0000
# Epoch 33/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112991416.7031 - mean_squared_error: 1112991360.0000
# Epoch 34/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1112987045.2447 - mean_squared_error: 1112987008.0000
# Epoch 35/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1112982597.6247 - mean_squared_error: 1112982656.0000
# Epoch 36/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112978050.5843 - mean_squared_error: 1112978176.0000
# Epoch 37/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112973520.8741 - mean_squared_error: 1112973568.0000
# Epoch 38/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112969047.2589 - mean_squared_error: 1112969088.0000
# Epoch 39/150
# 842/842 [==============================] - 0s 4us/sample - loss: 1112964203.6295 - mean_squared_error: 1112964224.0000
# Epoch 40/150
# 842/842 [==============================] - 0s 4us/sample - loss: 1112959600.9501 - mean_squared_error: 1112959616.0000
# Epoch 41/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112954579.6105 - mean_squared_error: 1112954624.0000
# Epoch 42/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112949654.1948 - mean_squared_error: 1112949632.0000
# Epoch 43/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112944552.7411 - mean_squared_error: 1112944512.0000
# Epoch 44/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112939434.8694 - mean_squared_error: 1112939392.0000
# Epoch 45/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1112934308.3325 - mean_squared_error: 1112934272.0000
# Epoch 46/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112928825.7672 - mean_squared_error: 1112928768.0000
# Epoch 47/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1112923412.0665 - mean_squared_error: 1112923520.0000
# Epoch 48/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1112917787.0594 - mean_squared_error: 1112917888.0000
# Epoch 49/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112912256.6081 - mean_squared_error: 1112912256.0000
# Epoch 50/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112906528.2280 - mean_squared_error: 1112906496.0000
# Epoch 51/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112900691.0024 - mean_squared_error: 1112900736.0000
# Epoch 52/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112894734.7458 - mean_squared_error: 1112894720.0000
# Epoch 53/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112888741.0926 - mean_squared_error: 1112888704.0000
# Epoch 54/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112882691.3444 - mean_squared_error: 1112882688.0000
# Epoch 55/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112876471.7910 - mean_squared_error: 1112876416.0000
# Epoch 56/150
# 842/842 [==============================] - 0s 8us/sample - loss: 1112869936.0380 - mean_squared_error: 1112870016.0000
# Epoch 57/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112863460.9406 - mean_squared_error: 1112863360.0000
# Epoch 58/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112856907.7055 - mean_squared_error: 1112856960.0000
# Epoch 59/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1112850212.3325 - mean_squared_error: 1112850176.0000
# Epoch 60/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112843311.4299 - mean_squared_error: 1112843264.0000
# Epoch 61/150
# 842/842 [==============================] - 0s 9us/sample - loss: 1112836401.2542 - mean_squared_error: 1112836352.0000
# Epoch 62/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1112829345.7482 - mean_squared_error: 1112829440.0000
# Epoch 63/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1112821897.4252 - mean_squared_error: 1112821888.0000
# Epoch 64/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1112814786.5843 - mean_squared_error: 1112814848.0000
# Epoch 65/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112807298.4323 - mean_squared_error: 1112807296.0000
# Epoch 66/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112799754.6413 - mean_squared_error: 1112799744.0000
# Epoch 67/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112792216.4751 - mean_squared_error: 1112792192.0000
# Epoch 68/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112784225.9002 - mean_squared_error: 1112784256.0000
# Epoch 69/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1112776103.8290 - mean_squared_error: 1112776192.0000
# Epoch 70/150
# 842/842 [==============================] - 0s 8us/sample - loss: 1112768354.0523 - mean_squared_error: 1112768384.0000
# Epoch 71/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1112760030.5558 - mean_squared_error: 1112760064.0000
# Epoch 72/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112751957.4347 - mean_squared_error: 1112751872.0000
# Epoch 73/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112743603.5344 - mean_squared_error: 1112743552.0000
# Epoch 74/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1112735031.9430 - mean_squared_error: 1112735104.0000
# Epoch 75/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112726409.1211 - mean_squared_error: 1112726400.0000
# Epoch 76/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112717727.3159 - mean_squared_error: 1112717696.0000
# Epoch 77/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112708752.1140 - mean_squared_error: 1112708864.0000
# Epoch 78/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112699846.5368 - mean_squared_error: 1112699904.0000
# Epoch 79/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112690814.4798 - mean_squared_error: 1112690816.0000
# Epoch 80/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112681662.9359 - mean_squared_error: 1112681600.0000
# Epoch 81/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112672309.9667 - mean_squared_error: 1112672256.0000
# Epoch 82/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112662666.3373 - mean_squared_error: 1112662528.0000
# Epoch 83/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112653440.6081 - mean_squared_error: 1112653440.0000
# Epoch 84/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112643739.0594 - mean_squared_error: 1112643712.0000
# Epoch 85/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112633750.4988 - mean_squared_error: 1112633728.0000
# Epoch 86/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112623839.4679 - mean_squared_error: 1112623872.0000
# Epoch 87/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112613761.9762 - mean_squared_error: 1112613760.0000
# Epoch 88/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112603440.3420 - mean_squared_error: 1112603392.0000
# Epoch 89/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112593172.8266 - mean_squared_error: 1112593152.0000
# Epoch 90/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112582383.8860 - mean_squared_error: 1112582272.0000
# Epoch 91/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112572078.8219 - mean_squared_error: 1112572032.0000
# Epoch 92/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112561200.9501 - mean_squared_error: 1112561152.0000
# Epoch 93/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112550206.0238 - mean_squared_error: 1112550144.0000
# Epoch 94/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112538849.9002 - mean_squared_error: 1112538880.0000
# Epoch 95/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112528038.3088 - mean_squared_error: 1112528128.0000
# Epoch 96/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112516413.1116 - mean_squared_error: 1112516352.0000
# Epoch 97/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112505080.0950 - mean_squared_error: 1112505088.0000
# Epoch 98/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112493356.0855 - mean_squared_error: 1112493312.0000
# Epoch 99/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112481708.6936 - mean_squared_error: 1112481792.0000
# Epoch 100/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112469787.0594 - mean_squared_error: 1112469888.0000
# Epoch 101/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112458203.2114 - mean_squared_error: 1112458240.0000
# Epoch 102/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112445773.5297 - mean_squared_error: 1112445696.0000
# Epoch 103/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112433503.4679 - mean_squared_error: 1112433536.0000
# Epoch 104/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112421204.2185 - mean_squared_error: 1112421120.0000
# Epoch 105/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112408814.0618 - mean_squared_error: 1112408832.0000
# Epoch 106/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112396185.9952 - mean_squared_error: 1112396160.0000
# Epoch 107/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112383370.3373 - mean_squared_error: 1112383360.0000
# Epoch 108/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112370244.7126 - mean_squared_error: 1112370176.0000
# Epoch 109/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112357514.1853 - mean_squared_error: 1112357504.0000
# Epoch 110/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112343927.7910 - mean_squared_error: 1112343936.0000
# Epoch 111/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1112330701.8337 - mean_squared_error: 1112330752.0000
# Epoch 112/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112317391.0499 - mean_squared_error: 1112317440.0000
# Epoch 113/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1112303564.9216 - mean_squared_error: 1112303616.0000
# Epoch 114/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112290001.6342 - mean_squared_error: 1112290048.0000
# Epoch 115/150
# 842/842 [==============================] - 0s 47us/sample - loss: 1112276235.4014 - mean_squared_error: 1112276224.0000
# Epoch 116/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112261956.1045 - mean_squared_error: 1112262016.0000
# Epoch 117/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112247346.1663 - mean_squared_error: 1112247424.0000
# Epoch 118/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112233053.9477 - mean_squared_error: 1112233088.0000
# Epoch 119/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112218775.8670 - mean_squared_error: 1112218752.0000
# Epoch 120/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112203702.7268 - mean_squared_error: 1112203776.0000
# Epoch 121/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112189137.0261 - mean_squared_error: 1112189056.0000
# Epoch 122/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112173758.9359 - mean_squared_error: 1112173824.0000
# Epoch 123/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112158534.0808 - mean_squared_error: 1112158592.0000
# Epoch 124/150
# 842/842 [==============================] - 0s 8us/sample - loss: 1112143204.3325 - mean_squared_error: 1112143232.0000
# Epoch 125/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112127249.3302 - mean_squared_error: 1112127232.0000
# Epoch 126/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112111411.9905 - mean_squared_error: 1112111360.0000
# Epoch 127/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112095304.0570 - mean_squared_error: 1112095360.0000
# Epoch 128/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112078996.6746 - mean_squared_error: 1112079104.0000
# Epoch 129/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1112062678.6508 - mean_squared_error: 1112062592.0000
# Epoch 130/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112046089.4252 - mean_squared_error: 1112045952.0000
# Epoch 131/150
# 842/842 [==============================] - 0s 8us/sample - loss: 1112029128.9691 - mean_squared_error: 1112029056.0000
# Epoch 132/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1112012104.3610 - mean_squared_error: 1112012032.0000
# Epoch 133/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1111994609.4062 - mean_squared_error: 1111994752.0000
# Epoch 134/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1111977344.6081 - mean_squared_error: 1111977472.0000
# Epoch 135/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1111959762.0903 - mean_squared_error: 1111959680.0000
# Epoch 136/150
# 842/842 [==============================] - 0s 5us/sample - loss: 1111941605.5487 - mean_squared_error: 1111941632.0000
# Epoch 137/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1111923941.3967 - mean_squared_error: 1111923968.0000
# Epoch 138/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1111905401.9192 - mean_squared_error: 1111905408.0000
# Epoch 139/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1111886811.5154 - mean_squared_error: 1111886848.0000
# Epoch 140/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1111868590.2138 - mean_squared_error: 1111868544.0000
# Epoch 141/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1111849189.8527 - mean_squared_error: 1111849216.0000
# Epoch 142/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1111829683.3824 - mean_squared_error: 1111829632.0000
# Epoch 143/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1111810907.2114 - mean_squared_error: 1111810944.0000
# Epoch 144/150
# 842/842 [==============================] - 0s 8us/sample - loss: 1111791189.4347 - mean_squared_error: 1111791104.0000
# Epoch 145/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1111771991.2589 - mean_squared_error: 1111772032.0000
# Epoch 146/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1111751674.8314 - mean_squared_error: 1111751552.0000
# Epoch 147/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1111731410.6983 - mean_squared_error: 1111731328.0000
# Epoch 148/150
# 842/842 [==============================] - 0s 6us/sample - loss: 1111711159.9430 - mean_squared_error: 1111711104.0000
# Epoch 149/150
# 842/842 [==============================] - 0s 8us/sample - loss: 1111690471.0689 - mean_squared_error: 1111690496.0000
# Epoch 150/150
# 842/842 [==============================] - 0s 7us/sample - loss: 1111669331.6105 - mean_squared_error: 1111669376.0000

# %% [markdown]
# ### Perceptron model evaulation metrics:

# %%
model1.evaluate(X_test, y_test)
# Out:
# 281/281 [==============================] - 0s 103us/sample - loss: 1068904031.6584 - mean_squared_error: 1068904064.0000
# [1068904031.658363, 1068904060.0]

# %% [markdown]
# ### R Squared score for perceptron

# %%
train_pred=model1.predict(X_train)
pred=model1.predict(X_test)

# %%
from sklearn.metrics import r2_score

print("train",r2_score(y_train, train_pred))
print("test",r2_score(y_test,pred))
# Out:
# train -2.6410569564837623
# test -2.8351247849546346

# %%
import tensorflow as tf
from tensorflow import keras as ker
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## 2. Multi layer perceptron

# %%
#step 1: build model
model1 = Sequential()
#input layer
model1.add(Dense(30, input_dim = 13, activation = 'relu'))
#hidden layers
model1.add(Dense(20, activation = 'relu'))
model1.add(Dense(10, activation = 'relu'))
#output layer
model1.add(Dense(1))

#step 2: make computational graph - compile
model1.compile(loss= 'mean_squared_error' , optimizer = 'adam',metrics = ['mean_squared_error'] )

#step 3: train the model - fit
model1.fit(X_train, y_train, epochs = 100, batch_size = 250);
# Out:
# Train on 842 samples
# Epoch 1/100
# 842/842 [==============================] - 0s 116us/sample - loss: 1113133260.4656 - mean_squared_error: 1113133312.0000
# Epoch 2/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1113128996.0285 - mean_squared_error: 1113128960.0000
# Epoch 3/100
# 842/842 [==============================] - 0s 6us/sample - loss: 1113125792.9881 - mean_squared_error: 1113125760.0000
# Epoch 4/100
# 842/842 [==============================] - 0s 6us/sample - loss: 1113123016.3610 - mean_squared_error: 1113123072.0000
# Epoch 5/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1113120499.9905 - mean_squared_error: 1113120512.0000
# Epoch 6/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1113117809.1021 - mean_squared_error: 1113117824.0000
# Epoch 7/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1113114953.1211 - mean_squared_error: 1113115008.0000
# Epoch 8/100
# 842/842 [==============================] - 0s 6us/sample - loss: 1113111620.2565 - mean_squared_error: 1113111552.0000
# Epoch 9/100
# 842/842 [==============================] - 0s 6us/sample - loss: 1113107753.6532 - mean_squared_error: 1113107712.0000
# Epoch 10/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1113103199.4679 - mean_squared_error: 1113103104.0000
# Epoch 11/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1113097682.3943 - mean_squared_error: 1113097728.0000
# Epoch 12/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1113090959.0499 - mean_squared_error: 1113090944.0000
# Epoch 13/100
# 842/842 [==============================] - 0s 6us/sample - loss: 1113083579.5914 - mean_squared_error: 1113083520.0000
# Epoch 14/100
# 842/842 [==============================] - 0s 9us/sample - loss: 1113075213.0736 - mean_squared_error: 1113075200.0000
# Epoch 15/100
# 842/842 [==============================] - 0s 6us/sample - loss: 1113066362.6793 - mean_squared_error: 1113066368.0000
# Epoch 16/100
# 842/842 [==============================] - 0s 6us/sample - loss: 1113056503.1829 - mean_squared_error: 1113056512.0000
# Epoch 17/100
# 842/842 [==============================] - 0s 9us/sample - loss: 1113045312.3040 - mean_squared_error: 1113045248.0000
# Epoch 18/100
# 842/842 [==============================] - 0s 6us/sample - loss: 1113033280.4561 - mean_squared_error: 1113033344.0000
# Epoch 19/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1113019375.4299 - mean_squared_error: 1113019392.0000
# Epoch 20/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1113003692.0855 - mean_squared_error: 1113003648.0000
# Epoch 21/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1112985957.2447 - mean_squared_error: 1112985984.0000
# Epoch 22/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1112965634.4323 - mean_squared_error: 1112965632.0000
# Epoch 23/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1112942600.5131 - mean_squared_error: 1112942592.0000
# Epoch 24/100
# 842/842 [==============================] - 0s 9us/sample - loss: 1112916849.1021 - mean_squared_error: 1112916864.0000
# Epoch 25/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1112887425.8242 - mean_squared_error: 1112887424.0000
# Epoch 26/100
# 842/842 [==============================] - 0s 6us/sample - loss: 1112854137.7672 - mean_squared_error: 1112854144.0000
# Epoch 27/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1112816189.2637 - mean_squared_error: 1112816256.0000
# Epoch 28/100
# 842/842 [==============================] - 0s 6us/sample - loss: 1112772816.5701 - mean_squared_error: 1112772736.0000
# Epoch 29/100
# 842/842 [==============================] - 0s 6us/sample - loss: 1112725087.6200 - mean_squared_error: 1112725120.0000
# Epoch 30/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1112669908.8266 - mean_squared_error: 1112669952.0000
# Epoch 31/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1112607614.6318 - mean_squared_error: 1112607616.0000
# Epoch 32/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1112535881.2732 - mean_squared_error: 1112535808.0000
# Epoch 33/100
# 842/842 [==============================] - 0s 6us/sample - loss: 1112454755.2684 - mean_squared_error: 1112454784.0000
# Epoch 34/100
# 842/842 [==============================] - 0s 10us/sample - loss: 1112364889.3872 - mean_squared_error: 1112364928.0000
# Epoch 35/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1112266295.0309 - mean_squared_error: 1112266368.0000
# Epoch 36/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1112153733.3207 - mean_squared_error: 1112153728.0000
# Epoch 37/100
# 842/842 [==============================] - 0s 9us/sample - loss: 1112029804.5416 - mean_squared_error: 1112029824.0000
# Epoch 38/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1111891651.1924 - mean_squared_error: 1111891712.0000
# Epoch 39/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1111739836.9596 - mean_squared_error: 1111739776.0000
# Epoch 40/100
# 842/842 [==============================] - 0s 9us/sample - loss: 1111571023.9620 - mean_squared_error: 1111571072.0000
# Epoch 41/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1111386912.8361 - mean_squared_error: 1111387008.0000
# Epoch 42/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1111183464.5891 - mean_squared_error: 1111183360.0000
# Epoch 43/100
# 842/842 [==============================] - 0s 9us/sample - loss: 1110958064.1900 - mean_squared_error: 1110958080.0000
# Epoch 44/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1110719523.8765 - mean_squared_error: 1110719488.0000
# Epoch 45/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1110449304.7791 - mean_squared_error: 1110449280.0000
# Epoch 46/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1110157797.2447 - mean_squared_error: 1110157824.0000
# Epoch 47/100
# 842/842 [==============================] - 0s 10us/sample - loss: 1109846082.5843 - mean_squared_error: 1109846144.0000
# Epoch 48/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1109503310.5938 - mean_squared_error: 1109503232.0000
# Epoch 49/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1109132620.9216 - mean_squared_error: 1109132672.0000
# Epoch 50/100
# 842/842 [==============================] - 0s 10us/sample - loss: 1108734322.9264 - mean_squared_error: 1108734336.0000
# Epoch 51/100
# 842/842 [==============================] - 0s 6us/sample - loss: 1108302263.6390 - mean_squared_error: 1108302336.0000
# Epoch 52/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1107836981.9667 - mean_squared_error: 1107836928.0000
# Epoch 53/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1107350174.8599 - mean_squared_error: 1107350144.0000
# Epoch 54/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1106807543.1829 - mean_squared_error: 1106807552.0000
# Epoch 55/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1106244139.9335 - mean_squared_error: 1106244096.0000
# Epoch 56/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1105624671.4679 - mean_squared_error: 1105624576.0000
# Epoch 57/100
# 842/842 [==============================] - 0s 11us/sample - loss: 1104972335.1259 - mean_squared_error: 1104972288.0000
# Epoch 58/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1104275319.9430 - mean_squared_error: 1104275328.0000
# Epoch 59/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1103533197.0736 - mean_squared_error: 1103533184.0000
# Epoch 60/100
# 842/842 [==============================] - 0s 11us/sample - loss: 1102736871.9810 - mean_squared_error: 1102736896.0000
# Epoch 61/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1101881956.9406 - mean_squared_error: 1101881984.0000
# Epoch 62/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1100977450.2613 - mean_squared_error: 1100977536.0000
# Epoch 63/100
# 842/842 [==============================] - 0s 6us/sample - loss: 1099999525.3967 - mean_squared_error: 1099999616.0000
# Epoch 64/100
# 842/842 [==============================] - 0s 9us/sample - loss: 1098951205.3967 - mean_squared_error: 1098951296.0000
# Epoch 65/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1097846420.2185 - mean_squared_error: 1097846400.0000
# Epoch 66/100
# 842/842 [==============================] - 0s 11us/sample - loss: 1096685261.3777 - mean_squared_error: 1096685312.0000
# Epoch 67/100
# 842/842 [==============================] - 0s 9us/sample - loss: 1095413151.1639 - mean_squared_error: 1095413120.0000
# Epoch 68/100
# 842/842 [==============================] - 0s 9us/sample - loss: 1094073424.5701 - mean_squared_error: 1094073472.0000
# Epoch 69/100
# 842/842 [==============================] - 0s 9us/sample - loss: 1092680851.6105 - mean_squared_error: 1092680832.0000
# Epoch 70/100
# 842/842 [==============================] - 0s 9us/sample - loss: 1091201496.0190 - mean_squared_error: 1091201536.0000
# Epoch 71/100
# 842/842 [==============================] - 0s 9us/sample - loss: 1089651862.8029 - mean_squared_error: 1089651840.0000
# Epoch 72/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1088003020.0095 - mean_squared_error: 1088003072.0000
# Epoch 73/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1086246007.1829 - mean_squared_error: 1086246016.0000
# Epoch 74/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1084484752.8741 - mean_squared_error: 1084484608.0000
# Epoch 75/100
# 842/842 [==============================] - 0s 9us/sample - loss: 1082586377.5772 - mean_squared_error: 1082586368.0000
# Epoch 76/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1080556237.9857 - mean_squared_error: 1080556288.0000
# Epoch 77/100
# 842/842 [==============================] - 0s 9us/sample - loss: 1078432114.3183 - mean_squared_error: 1078432128.0000
# Epoch 78/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1076215527.9810 - mean_squared_error: 1076215552.0000
# Epoch 79/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1073875599.0499 - mean_squared_error: 1073875584.0000
# Epoch 80/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1071404302.5938 - mean_squared_error: 1071404352.0000
# Epoch 81/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1068802587.5154 - mean_squared_error: 1068802560.0000
# Epoch 82/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1066136111.5819 - mean_squared_error: 1066136128.0000
# Epoch 83/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1063312940.6936 - mean_squared_error: 1063312896.0000
# Epoch 84/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1060343092.5986 - mean_squared_error: 1060343040.0000
# Epoch 85/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1057282369.2162 - mean_squared_error: 1057282304.0000
# Epoch 86/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1054121273.1591 - mean_squared_error: 1054121280.0000
# Epoch 87/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1050745474.1283 - mean_squared_error: 1050745472.0000
# Epoch 88/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1047322899.6105 - mean_squared_error: 1047322880.0000
# Epoch 89/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1043747462.3848 - mean_squared_error: 1043747456.0000
# Epoch 90/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1039995992.7791 - mean_squared_error: 1039995968.0000
# Epoch 91/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1036146619.4394 - mean_squared_error: 1036146624.0000
# Epoch 92/100
# 842/842 [==============================] - 0s 9us/sample - loss: 1032076943.2019 - mean_squared_error: 1032076992.0000
# Epoch 93/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1027862582.8789 - mean_squared_error: 1027862592.0000
# Epoch 94/100
# 842/842 [==============================] - 0s 7us/sample - loss: 1023543663.1259 - mean_squared_error: 1023543552.0000
# Epoch 95/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1019039618.1283 - mean_squared_error: 1019039680.0000
# Epoch 96/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1014248463.3539 - mean_squared_error: 1014248448.0000
# Epoch 97/100
# 842/842 [==============================] - 0s 8us/sample - loss: 1009570828.0095 - mean_squared_error: 1009570880.0000
# Epoch 98/100
# 842/842 [==============================] - 0s 9us/sample - loss: 1004601680.4181 - mean_squared_error: 1004601664.0000
# Epoch 99/100
# 842/842 [==============================] - 0s 7us/sample - loss: 999369254.0048 - mean_squared_error: 999369280.0000
# Epoch 100/100
# 842/842 [==============================] - 0s 8us/sample - loss: 994028818.5463 - mean_squared_error: 994028864.0000

# %% [markdown]
# ### Perceptron model evaulation metrics:

# %%
model1.evaluate(X_train, y_train)
# Out:
# 842/842 [==============================] - 0s 51us/sample - loss: 990299204.4086 - mean_squared_error: 990299264.0000
# [990299204.4085511, 990299260.0]

# %%
model1.evaluate(X_test, y_test)
# Out:
# 281/281 [==============================] - 0s 78us/sample - loss: 953129668.3274 - mean_squared_error: 953129600.0000
# [953129668.3274021, 953129600.0]

# %% [markdown]
# ### R Squared score for perceptron

# %%
train_pred=model1.predict(X_train)
pred=model1.predict(X_test)

# %%
from sklearn.metrics import r2_score

print("train",r2_score(y_train, train_pred))
print("test",r2_score(y_test,pred))
# Out:
# train -2.243573440656869
# test -2.419737586797142
